# %%
from src.shopline import ShopLine
import json

shopline = ShopLine()

# %%
orders = shopline.get_outstanding_orders()
# Out:
# 2025-07-23 17:06:19.570 | INFO     | src.shopline:get_outstanding_orders:158 - Search Params: {'per_page': 200, 'delivery_option_id': '68281a2f3451b7000c4f5d7b', 'status': 'confirmed', 'delivery_statuses[]': ['pending', 'shipping', 'shipped', 'returning']}
# 2025-07-23 17:06:19.571 | INFO     | src.shopline:search_order:134 - Full Search URL: https://open.shopline.io/v1/orders/search?per_page=200&delivery_option_id=68281a2f3451b7000c4f5d7b&status=confirmed&delivery_statuses[]=pending&delivery_statuses[]=shipping&delivery_statuses[]=shipped&delivery_statuses[]=returning
# 2025-07-23 17:06:27.086 | DEBUG    | src.shopline:response_handler:49 - Request Succeed

# %%
print(orders["items"][0]["confirmed_at"])
# Out:
# 2025-07-23T08:45:06.342+00:00
